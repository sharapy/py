# %%
import requests, bs4, lxml

# %%
URL = "https://www.linkedin.com/jobs/search/?currentJobId=3740104314&geoId=103644278&keywords=Machine%20Learning%20Engineer&location=United%20States&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true"
result = requests.get(URL)
soup = bs4.BeautifulSoup(result.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="d_jobs_guest_search" name="pageKey"/>
# <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1386" data-browser-id="8659a9fd-e02b-4bf5-8df9-d97f92d30321" data-call-tree-id="AAYJky/fjwbVB6BTa8Cs1A==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;UvnRsPO6RnCst5eEY2uOQg==" data-service-name="jobs-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/jobs/machine-learning-engineer-jobs" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
# <script>
# ...

# %%
all_sr = soup.select(".sr-only")

# %%
for each in all_sr:
    print(each.text.strip())
# Out:
# LinkedIn
# Expand search
# Dismiss
# Dismiss
# Dismiss
# Dismiss
# Dismiss
#
#
# Dismiss
#
# Dismiss
# Machine Learning Engineer
# AI/ML Machine Learning Engineer - Early Career
# Machine Learning Engineer
# Software Engineer - AI/ML
# Machine Learning Research Engineer
# Entry-Level Data Scientist Engineer
# Machine Learning Engineer Intern
# Machine Learning Engineer
# Machine Learning Engineer
# Machine Learning Engineer
# Machine Learning Engineer
# Machine Learning Engineer
# Machine Learning Engineer, Predictive
# Machine Learning Engineer
# Machine Learning Software Engineer
# Machine Learning Engineer- Graduate Intern
# Junior Machine Learning Engineer
# Machine Learning Engineer
# Machine Learning Engineer
# A/AI Machine Learning Engineer
# Entry level Data Scientist
# Machine Learning Engineer
# Machine Learning Engineer
# Data Scientist with AI/ML
# LinkedIn
# Dismiss

# %%
mydivs = soup.find_all("div", "data-view-name" )

# %%
mydivs
# Out:
# []
